# %%
base_dir = './'
data_dir = './data/'

# %%
import os
import sys

sys.path.insert(0, os.getcwd() + '\\src')

# %%
from preprocess import *

# %%
data = load_data(data_dir + 'USD2FX_BIS_daily_avg.csv', 
                 start_date = '2002-01-01', 
                 end_date = '2022-10-31'
                )
data
# Out:
#                AED      ALL         ARS       EUR       AUD       BAM  \
# Date
# 2002-01-01     NaN  136.800         NaN       NaN       NaN       NaN
# 2002-01-02  3.6725  136.800    0.999657  1.106439  1.947665       NaN
# 2002-01-03  3.6725  136.375    0.999104  1.106684  1.938911       NaN
# 2002-01-04  3.6725  137.150    0.999095  1.116819  1.929864       NaN
# 2002-01-05     NaN      NaN         NaN       NaN       NaN       NaN
# ...            ...      ...         ...       ...       ...       ...
# 2022-10-27  3.6725  117.830  155.698300  0.996314  1.555246  1.951342
# 2022-10-28  3.6725  118.880  156.016700  1.004924  1.558738  1.948620
# 2022-10-29  3.6725      NaN         NaN       NaN       NaN  1.965461
# 2022-10-30  3.6725      NaN         NaN       NaN       NaN  1.965461
# 2022-10-31  3.6725  118.760  156.895000  1.008675  1.566371  1.965461
#
#                EUR.1       BGN    BHD     BND  ...        TRY     TTD  \
# ...

# %%
n_timestamps = 28
lag = 1

save_dir = data_dir+f'/n_timestamps_{n_timestamps}__lag_{lag}'

# %%
data = cleanse_data(data, save_dir=save_dir)
data
# Out:
#                  AUD       BGN       BRL       CAD       CHF       CNY  \
# Date
# 2002-01-02  0.194767  0.215966  0.230825  0.159726  0.164118  0.827705
# 2002-01-03  0.193891  0.216135  0.229405  0.159606  0.164409  0.827700
# 2002-01-04  0.192986  0.218215  0.230802  0.159761  0.165166  0.827697
# 2002-01-07  0.192925  0.219427  0.235295  0.159596  0.165289  0.827703
# 2002-01-08  0.192053  0.219329  0.233853  0.160141  0.165035  0.827702
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-25  0.158189  0.198337  0.529906  0.137278  0.100274  0.730879
# 2022-10-26  0.154305  0.195131  0.528225  0.135369  0.098942  0.717829
# 2022-10-27  0.155525  0.194859  0.536903  0.136216  0.099123  0.722846
# 2022-10-28  0.155874  0.196543  0.535323  0.136087  0.099688  0.725143
# 2022-10-31  0.156637  0.197277  0.531511  0.136706  0.100111  0.730079
#
#                  COP       CZK       DKK       DZD  ...       PHP       PLN  \
# ...

# %%
extracted = extract_data(data, n_timestamps=5, lag=1, 
                         save_dir=save_dir
                        )
print('Data :', extracted['data'].shape)
print('Dates :', extracted['dates'].shape)
print('Positional Encoding :', extracted['pos_enc'].shape)
# Out:
# Data : torch.Size([5332, 5, 34])
# Dates : (5332,)
# Positional Encoding : torch.Size([5332, 5, 2])

# %%
data_split = split_data(extracted, save_dir=save_dir)
print('Train :', data_split['train']['data'].shape[0])
print('Valid :', data_split['valid']['data'].shape[0])
print('Test  :', data_split['test']['data'].shape[0])
# Out:
# Train : 3412
# Valid : 853
# Test  : 1067
